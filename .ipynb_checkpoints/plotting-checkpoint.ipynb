# %%
# %pylab inline
from scipy.optimize import curve_fit
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d = pd.read_excel("C:\\Users\\RAJAT GUPTA\\Desktop\\OHR\\Online-Writing-Recogonition\\datafile.xls")
prev=0
curr=0
for x in dd.index:
    if(dd.loc[x].X_value=='\n'):
        curr=x
        #print(dd.loc[curr].X_value)
        d1=d[prev:curr]
        rgb = (random.random(), random.random(), random.random())
        plt.plot(d1.X_value.astype(int),-1*d1.Y_value.astype(int), c=numpy.random.rand(3,))
        prev=curr+1

plt.show()
